# %% [markdown]
# # Required imports

# %%
# %load_ext autoreload
# %autoreload 2

import joblib
import os
from sklearn.model_selection import train_test_split
from FaceBinaryDataset import FaceBinaryDataset
from build_pipeline import build_pipeline
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
import numpy as np
from sklearn.metrics import precision_score, recall_score
import time
import pandas as pd
import cv2
from PIL import ImageEnhance
import warnings
import matplotlib.pyplot as plt
import seaborn as sns

from metrics import evaluate_model,measure_prediction_time
from perturbations import test_model_on_perturbations
# Out:
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # Load Dataset

# %%
dataset = FaceBinaryDataset("dataset/output_dataset", dimension=160)

images = []
labels = []

for i in range(len(dataset)):
    img, label, userid = dataset[i]

    if img is None:
        continue

    images.append(img)
    labels.append(label)

images = np.array(images)
labels = np.array(labels)
# Out:
# No face detected in: dataset/output_dataset/authorized/user_00041/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00041/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00041/img_008.jpg
# No face detected in: dataset/output_dataset/authorized/user_00079/img_003.jpg
# No face detected in: dataset/output_dataset/authorized/user_00084/img_003.jpg
# No face detected in: dataset/output_dataset/authorized/user_00084/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00084/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00070/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00070/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00077/img_003.jpg
# No face detected in: dataset/output_dataset/authorized/user_00077/img_006.jpg
# No face detected in: dataset/output_dataset/authorized/user_00083/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00083/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00083/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00048/img_005.jpg
# No face detected in: dataset/output_dataset/authorized/user_00048/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00048/img_008.jpg
# No face detected in: dataset/output_dataset/authorized/user_00048/img_018.jpg
# No face detected in: dataset/output_dataset/authorized/user_00023/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00023/img_001.jpg
# No face detected in: dataset/output_dataset/authorized/user_00023/img_002.jpg
# No face detected in: dataset/output_dataset/authorized/user_00023/img_007.jpg
# No face detected in: dataset/output_dataset/authorized/user_00023/img_005.jpg
# No face detected in: dataset/output_dataset/authorized/user_00023/img_009.jpg
# No face detected in: dataset/output_dataset/authorized/user_00023/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00023/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00024/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00024/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00024/img_006.jpg
# No face detected in: dataset/output_dataset/authorized/user_00024/img_007.jpg
# No face detected in: dataset/output_dataset/authorized/user_00024/img_005.jpg
# No face detected in: dataset/output_dataset/authorized/user_00024/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00024/img_010.jpg
# No face detected in: dataset/output_dataset/authorized/user_00024/img_009.jpg
# No face detected in: dataset/output_dataset/authorized/user_00024/img_018.jpg
# No face detected in: dataset/output_dataset/authorized/user_00024/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00012/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00012/img_003.jpg
# No face detected in: dataset/output_dataset/authorized/user_00012/img_016.jpg
# No face detected in: dataset/output_dataset/authorized/user_00012/img_010.jpg
# No face detected in: dataset/output_dataset/authorized/user_00012/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00015/img_007.jpg
# No face detected in: dataset/output_dataset/authorized/user_00015/img_004.jpg
# No face detected in: dataset/output_dataset/authorized/user_00015/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00082/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00082/img_017.jpg
# No face detected in: dataset/output_dataset/authorized/user_00082/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00082/img_009.jpg
# No face detected in: dataset/output_dataset/authorized/user_00082/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00076/img_004.jpg
# No face detected in: dataset/output_dataset/authorized/user_00049/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00049/img_002.jpg
# No face detected in: dataset/output_dataset/authorized/user_00049/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00049/img_010.jpg
# No face detected in: dataset/output_dataset/authorized/user_00049/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00071/img_017.jpg
# No face detected in: dataset/output_dataset/authorized/user_00071/img_016.jpg
# No face detected in: dataset/output_dataset/authorized/user_00071/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00071/img_004.jpg
# No face detected in: dataset/output_dataset/authorized/user_00071/img_008.jpg
# No face detected in: dataset/output_dataset/authorized/user_00085/img_006.jpg
# No face detected in: dataset/output_dataset/authorized/user_00085/img_007.jpg
# No face detected in: dataset/output_dataset/authorized/user_00085/img_004.jpg
# No face detected in: dataset/output_dataset/authorized/user_00047/img_003.jpg
# No face detected in: dataset/output_dataset/authorized/user_00047/img_016.jpg
# No face detected in: dataset/output_dataset/authorized/user_00047/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00047/img_009.jpg
# No face detected in: dataset/output_dataset/authorized/user_00078/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00078/img_001.jpg
# No face detected in: dataset/output_dataset/authorized/user_00078/img_004.jpg
# No face detected in: dataset/output_dataset/authorized/user_00078/img_009.jpg
# No face detected in: dataset/output_dataset/authorized/user_00078/img_018.jpg
# No face detected in: dataset/output_dataset/authorized/user_00078/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00014/img_002.jpg
# No face detected in: dataset/output_dataset/authorized/user_00014/img_016.jpg
# No face detected in: dataset/output_dataset/authorized/user_00014/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00014/img_004.jpg
# No face detected in: dataset/output_dataset/authorized/user_00025/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00025/img_001.jpg
# No face detected in: dataset/output_dataset/authorized/user_00025/img_006.jpg
# No face detected in: dataset/output_dataset/authorized/user_00025/img_007.jpg
# No face detected in: dataset/output_dataset/authorized/user_00025/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00025/img_018.jpg
# No face detected in: dataset/output_dataset/authorized/user_00022/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00022/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00007/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00007/img_016.jpg
# No face detected in: dataset/output_dataset/authorized/user_00007/img_005.jpg
# No face detected in: dataset/output_dataset/authorized/user_00007/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00007/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00038/img_010.jpg
# No face detected in: dataset/output_dataset/authorized/user_00038/img_004.jpg
# No face detected in: dataset/output_dataset/authorized/user_00031/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00036/img_016.jpg
# No face detected in: dataset/output_dataset/authorized/user_00036/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00036/img_008.jpg
# No face detected in: dataset/output_dataset/authorized/user_00036/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00009/img_003.jpg
# No face detected in: dataset/output_dataset/authorized/user_00009/img_002.jpg
# No face detected in: dataset/output_dataset/authorized/user_00009/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00009/img_004.jpg
# No face detected in: dataset/output_dataset/authorized/user_00096/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00096/img_001.jpg
# No face detected in: dataset/output_dataset/authorized/user_00096/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00096/img_009.jpg
# No face detected in: dataset/output_dataset/authorized/user_00096/img_018.jpg
# No face detected in: dataset/output_dataset/authorized/user_00062/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00065/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00091/img_001.jpg
# No face detected in: dataset/output_dataset/authorized/user_00091/img_002.jpg
# No face detected in: dataset/output_dataset/authorized/user_00091/img_016.jpg
# No face detected in: dataset/output_dataset/authorized/user_00091/img_007.jpg
# No face detected in: dataset/output_dataset/authorized/user_00091/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00091/img_009.jpg
# No face detected in: dataset/output_dataset/authorized/user_00091/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00098/img_001.jpg
# No face detected in: dataset/output_dataset/authorized/user_00098/img_017.jpg
# No face detected in: dataset/output_dataset/authorized/user_00098/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00053/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00054/img_003.jpg
# No face detected in: dataset/output_dataset/authorized/user_00054/img_007.jpg
# No face detected in: dataset/output_dataset/authorized/user_00037/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00037/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00037/img_004.jpg
# No face detected in: dataset/output_dataset/authorized/user_00037/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00008/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00008/img_017.jpg
# No face detected in: dataset/output_dataset/authorized/user_00008/img_005.jpg
# No face detected in: dataset/output_dataset/authorized/user_00030/img_002.jpg
# No face detected in: dataset/output_dataset/authorized/user_00030/img_006.jpg
# No face detected in: dataset/output_dataset/authorized/user_00030/img_005.jpg
# No face detected in: dataset/output_dataset/authorized/user_00030/img_010.jpg
# No face detected in: dataset/output_dataset/authorized/user_00030/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00030/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00006/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00006/img_002.jpg
# No face detected in: dataset/output_dataset/authorized/user_00006/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00006/img_006.jpg
# No face detected in: dataset/output_dataset/authorized/user_00006/img_005.jpg
# No face detected in: dataset/output_dataset/authorized/user_00006/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00006/img_008.jpg
# No face detected in: dataset/output_dataset/authorized/user_00039/img_006.jpg
# No face detected in: dataset/output_dataset/authorized/user_00039/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00001/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00001/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00001/img_007.jpg
# No face detected in: dataset/output_dataset/authorized/user_00001/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00001/img_005.jpg
# No face detected in: dataset/output_dataset/authorized/user_00001/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00055/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00099/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00099/img_005.jpg
# No face detected in: dataset/output_dataset/authorized/user_00099/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00099/img_010.jpg
# No face detected in: dataset/output_dataset/authorized/user_00099/img_018.jpg
# No face detected in: dataset/output_dataset/authorized/user_00052/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00052/img_001.jpg
# No face detected in: dataset/output_dataset/authorized/user_00052/img_006.jpg
# No face detected in: dataset/output_dataset/authorized/user_00052/img_004.jpg
# No face detected in: dataset/output_dataset/authorized/user_00090/img_006.jpg
# No face detected in: dataset/output_dataset/authorized/user_00090/img_005.jpg
# No face detected in: dataset/output_dataset/authorized/user_00090/img_010.jpg
# No face detected in: dataset/output_dataset/authorized/user_00090/img_008.jpg
# No face detected in: dataset/output_dataset/authorized/user_00064/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00064/img_010.jpg
# No face detected in: dataset/output_dataset/authorized/user_00064/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00064/img_018.jpg
# No face detected in: dataset/output_dataset/authorized/user_00063/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00097/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00097/img_002.jpg
# No face detected in: dataset/output_dataset/authorized/user_00097/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00097/img_009.jpg
# No face detected in: dataset/output_dataset/authorized/user_00097/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00018/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00018/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00027/img_017.jpg
# No face detected in: dataset/output_dataset/authorized/user_00027/img_016.jpg
# No face detected in: dataset/output_dataset/authorized/user_00027/img_005.jpg
# No face detected in: dataset/output_dataset/authorized/user_00027/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00020/img_002.jpg
# No face detected in: dataset/output_dataset/authorized/user_00020/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00020/img_009.jpg
# No face detected in: dataset/output_dataset/authorized/user_00020/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00029/img_016.jpg
# No face detected in: dataset/output_dataset/authorized/user_00029/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00016/img_017.jpg
# No face detected in: dataset/output_dataset/authorized/user_00016/img_010.jpg
# No face detected in: dataset/output_dataset/authorized/user_00045/img_016.jpg
# No face detected in: dataset/output_dataset/authorized/user_00045/img_011.jpg
# No face detected in: dataset/output_dataset/authorized/user_00045/img_018.jpg
# No face detected in: dataset/output_dataset/authorized/user_00042/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00089/img_017.jpg
# No face detected in: dataset/output_dataset/authorized/user_00089/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00074/img_017.jpg
# No face detected in: dataset/output_dataset/authorized/user_00074/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00074/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00080/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00080/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00080/img_003.jpg
# No face detected in: dataset/output_dataset/authorized/user_00080/img_012.jpg
# No face detected in: dataset/output_dataset/authorized/user_00080/img_019.jpg
# No face detected in: dataset/output_dataset/authorized/user_00087/img_013.jpg
# No face detected in: dataset/output_dataset/authorized/user_00087/img_020.jpg
# No face detected in: dataset/output_dataset/authorized/user_00073/img_014.jpg
# No face detected in: dataset/output_dataset/authorized/user_00073/img_015.jpg
# No face detected in: dataset/output_dataset/authorized/user_00073/img_017.jpg
# No face detected in: dataset/output_dataset/authorized/user_00073/img_016.jpg
# No face detected in: dataset/output_dataset/authorized/user_
jpg
# No face detected in: dataset/output_dataset/unauthorized/user_00033/img_019.jpg
# No face detected in: dataset/output_dataset/unauthorized/user_00002/img_015.jpg
# No face detected in: dataset/output_dataset/unauthorized/user_00002/img_017.jpg
# No face detected in: dataset/output_dataset/unauthorized/user_00002/img_005.jpg
# No face detected in: dataset/output_dataset/unauthorized/user_00002/img_011.jpg
# No face detected in: dataset/output_dataset/unauthorized/user_00002/img_019.jpg
# No face detected in: dataset/output_dataset/unauthorized/user_00005/img_003.jpg
# No face detected in: dataset/output_dataset/unauthorized/user_00005/img_011.jpg

# %% [markdown]
# # Outer cross validation

# %%
seed = 42

cv_outer = RepeatedStratifiedKFold(n_splits=2, n_repeats=1, random_state=seed)

# %% [markdown]
# # LBP

# %%
param_grid = {
    'features__extractor__num_points': [8, 16, 24],
    'features__extractor__radius'    : [1, 2, 8],
    'classifier__kernel': ['linear', 'rbf'],
    'classifier__C': [0.1, 1, 100]
}

LBP_far_to_statistic=[]
LBP_frr_to_statistic=[]
LBP_precision_to_statistic=[]
LBP_recall_to_statistic=[]

LBP_ptr_results_to_statistic=[]
LBP_time_results_to_statistic=[]

for fold_idx, (train_idx, test_idx) in enumerate(cv_outer.split(images, labels), 1):
    X_train, X_test = images[train_idx], images[test_idx]
    y_train, y_test = labels[train_idx], labels[test_idx]

    pipeline = build_pipeline("lbp")

    cv_inner = RepeatedStratifiedKFold(n_splits=2, n_repeats=1, random_state=seed)

    grid_search_SVC = GridSearchCV(
        pipeline,
        param_grid=param_grid,
        cv=cv_inner,
        verbose=2,
        n_jobs=-1,
    )

    grid_search_SVC.fit(X_train, y_train)
    
    best_model = grid_search_SVC.best_estimator_

    far, frr, precision, recall = evaluate_model(best_model, X_test, y_test)

    LBP_far_to_statistic.append(far)
    LBP_frr_to_statistic.append(frr)
    LBP_precision_to_statistic.append(precision)
    LBP_recall_to_statistic.append(recall)

    ptr_results = test_model_on_perturbations(best_model, X_test, y_test)
    time_results = measure_prediction_time(best_model, X_test)
    
    LBP_time_results_to_statistic.append(time_results)
    LBP_ptr_results_to_statistic.append(ptr_results)
    

    print(f"Fold {fold_idx}: precision = {precision:.4f}")
# Out:
# Fitting 2 folds for each of 54 candidates, totalling 108 fits
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Fold 1: accuracy = 0.5461
# Fitting 2 folds for each of 54 candidates, totalling 108 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 32
#      22 cv_inner = RepeatedStratifiedKFold(n_splits=2, n_repeats=1, random_state=seed)
#      24 grid_search_SVC = GridSearchCV(
#      25     pipeline,
#      26     param_grid=param_grid,
#    (...)
#      29     n_jobs=-1,
#      30 )
# ---> 32 grid_search_SVC.fit(X_train, y_train)
#      34 best_model = grid_search_SVC.best_estimator_
#      36 far, frr, precision, recall = evaluate_model(best_model, X_test, y_test)
#
# File ~/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File ~/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/sklearn/model_selection/_search.py:1571, in GridSearchCV._run_search(self, evaluate_candidates)
#    1569 def _run_search(self, evaluate_candidates):
#    1570     """Search all candidates in param_grid"""
# -> 1571     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File ~/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/joblib/parallel.py:2007, in Parallel.__call__(self, iterable)
#    2001 # The first item from the output is blank, but it makes the interpreter
#    2002 # progress until it enters the Try/Except block of the generator and
#    2003 # reaches the first `yield` statement. This starts the asynchronous
#    2004 # dispatch of the tasks to the workers.
#    2005 next(output)
# -> 2007 return output if self.return_generator else list(output)
#
# File ~/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/joblib/parallel.py:1650, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1647     yield
#    1649     with self._backend.retrieval_context():
# -> 1650         yield from self._retrieve()
#    1652 except GeneratorExit:
#    1653     # The generator has been garbage collected before being fully
#    1654     # consumed. This aborts the remaining tasks if possible and warn
#    1655     # the user if necessary.
#    1656     self._exception = True
#
# File ~/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/joblib/parallel.py:1762, in Parallel._retrieve(self)
#    1757 # If the next job is not ready for retrieval yet, we just wait for
#    1758 # async callbacks to progress.
#    1759 if ((len(self._jobs) == 0) or
#    1760     (self._jobs[0].get_status(
#    1761         timeout=self.timeout) == TASK_PENDING)):
# -> 1762     time.sleep(0.01)
#    1763     continue
#    1765 # We need to be careful: the job list can be filling up as
#    1766 # we empty it and Python list are not thread-safe by
#    1767 # default hence the use of the lock
#
# KeyboardInterrupt:

# %% [markdown]
# # Saving results

# %%
df_general = pd.DataFrame({
    'FAR': LBP_far_to_statistic,
    'FRR': LBP_frr_to_statistic,
    'Precision': LBP_precision_to_statistic,
    'Recall': LBP_recall_to_statistic,
    'Time': LBP_time_results_to_statistic
})
df_general.to_csv("LBP_general_statistics.csv", index=False)
for fold in LBP_ptr_results_to_statistic:
    df_perturbations = pd.DataFrame(fold)
    df_perturbations.to_csv("LBP_perturbation_statistics.csv", index=False)

# %% [markdown]
# # HOG

# %%
param_grid = {
    'features__extractor__orientations': [8, 12],
    'features__extractor__pixels_per_cell': [(4, 4), (8, 8)],
    'features__extractor__cells_per_block': [(2, 2), (3, 3)],

    'classifier__kernel': ['linear', 'rbf'],
    'classifier__C': [0.1, 1, 100]
}

HOG_far_to_statistic=[]
HOG_frr_to_statistic=[]
HOG_precision_to_statistic=[]
HOG_recall_to_statistic=[]

HOG_ptr_results_to_statistic=[]
HOG_time_results_to_statistic=[]

for fold_idx, (train_idx, test_idx) in enumerate(cv_outer.split(images, labels), 1):
    X_train, X_test = images[train_idx], images[test_idx]
    y_train, y_test = labels[train_idx], labels[test_idx]

    pipeline = build_pipeline("hog")

    cv_inner = RepeatedStratifiedKFold(n_splits=3, n_repeats=1, random_state=seed)

    grid_search_SVC = GridSearchCV(
        pipeline,
        param_grid=param_grid,
        cv=cv_inner,
        verbose=2,
        n_jobs=-1,
    )

    grid_search_SVC.fit(X_train, y_train)

    best_model = grid_search_SVC.best_estimator_

    far, frr, precision, recall = evaluate_model(best_model, X_test, y_test)

    HOG_far_to_statistic.append(far)
    HOG_frr_to_statistic.append(frr)
    HOG_precision_to_statistic.append(precision)
    HOG_recall_to_statistic.append(recall)


    ptr_results = test_model_on_perturbations(best_model, X_test, y_test)
    time_results = measure_prediction_time(best_model, X_test)

    HOG_time_results_to_statistic.append(time_results)
    HOG_ptr_results_to_statistic.append(ptr_results)


    print(f"Fold {fold_idx}: precision = {precision:.4f}")
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/dawid/PycharmProjects/ImbalancedDataProject/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # Saving results

# %%
df_general = pd.DataFrame({
    'FAR': HOG_far_to_statistic,
    'FRR': HOG_frr_to_statistic,
    'Precision': HOG_precision_to_statistic,
    'Recall': HOG_recall_to_statistic,
    'Time': HOG_time_results_to_statistic
})
df_general.to_csv("HOG_general_statistics.csv", index=False)

for fold in HOG_ptr_results_to_statistic:
    df_perturbations = pd.DataFrame(fold)
    df_perturbations.to_csv("HOG_perturbation_statistics.csv", index=False)

# %% [markdown]
# # CNN

# %%
param_grid = {
    'classifier__kernel': ['linear', 'rbf'],
    'classifier__C': [0.1, 1, 100]
}

CNN_far_to_statistic=[]
CNN_frr_to_statistic=[]
CNN_precision_to_statistic=[]
CNN_recall_to_statistic=[]

CNN_ptr_results_to_statistic=[]
CNN_time_results_to_statistic=[]

for fold_idx, (train_idx, test_idx) in enumerate(cv_outer.split(images, labels), 1):
    X_train, X_test = images[train_idx], images[test_idx]
    y_train, y_test = labels[train_idx], labels[test_idx]

    pipeline = build_pipeline("cnn")

    cv_inner = RepeatedStratifiedKFold(n_splits=3, n_repeats=1, random_state=seed)

    grid_search_SVC = GridSearchCV(
        pipeline,
        param_grid=param_grid,
        cv=cv_inner,
        verbose=2,
        n_jobs=-1,
    )

    grid_search_SVC.fit(X_train, y_train)

    best_model = grid_search_SVC.best_estimator_

    far, frr, precision, recall = evaluate_model(best_model, X_test, y_test)

    CNN_far_to_statistic.append(far)
    CNN_frr_to_statistic.append(frr)
    CNN_precision_to_statistic.append(precision)
    CNN_recall_to_statistic.append(recall)


    ptr_results = test_model_on_perturbations(best_model, X_test, y_test)
    time_results = measure_prediction_time(best_model, X_test)

    CNN_time_results_to_statistic.append(time_results)
    CNN_ptr_results_to_statistic.append(ptr_results)


    print(f"Fold {fold_idx}: precision = {precision:.4f}")

# %% [markdown]
# # Save results

# %%
df_general = pd.DataFrame({
    'FAR': CNN_far_to_statistic,
    'FRR': CNN_frr_to_statistic,
    'Precision': CNN_precision_to_statistic,
    'Recall': CNN_recall_to_statistic,
    'Time': CNN_time_results_to_statistic
})
df_general.to_csv("CNN_general_statistics.csv", index=False)

for fold in CNN_ptr_results_to_statistic:
    df_perturbations = pd.DataFrame(fold)
    df_perturbations.to_csv("CNN_perturbation_statistics.csv", index=False)

# %% [markdown]
# # FaceNet

# %%
param_grid = {
    'classifier__kernel': ['linear', 'rbf'],
    'classifier__C': [0.1, 1, 100]
}

FN_far_to_statistic=[]
FN_frr_to_statistic=[]
FN_precision_to_statistic=[]
FN_recall_to_statistic=[]

FN_ptr_results_to_statistic=[]
FN_time_results_to_statistic=[]

for fold_idx, (train_idx, test_idx) in enumerate(cv_outer.split(images, labels), 1):
    X_train, X_test = images[train_idx], images[test_idx]
    y_train, y_test = labels[train_idx], labels[test_idx]

    pipeline = build_pipeline("facenet")

    cv_inner = RepeatedStratifiedKFold(n_splits=3, n_repeats=1, random_state=seed)

    grid_search_SVC = GridSearchCV(
        pipeline,
        param_grid=param_grid,
        cv=cv_inner,
        verbose=2,
        n_jobs=-1,
    )

    grid_search_SVC.fit(X_train, y_train)

    best_model = grid_search_SVC.best_estimator_

    far, frr, precision, recall = evaluate_model(best_model, X_test, y_test)

    FN_far_to_statistic.append(far)
    FN_frr_to_statistic.append(frr)
    FN_precision_to_statistic.append(precision)
    FN_recall_to_statistic.append(recall)

    far_ptr, frr_ptr, precision_ptr, recall_ptr = test_model_on_perturbations(best_model, X_test, y_test)

    ptr_results = test_model_on_perturbations(best_model, X_test, y_test)
    time_results = measure_prediction_time(best_model, X_test)

    FN_time_results_to_statistic.append(time_results)
    FN_ptr_results_to_statistic.append(ptr_results)


    print(f"Fold {fold_idx}: precision = {precision:.4f}")

# %% [markdown]
# # Save results

# %%
df_general = pd.DataFrame({
    'FAR': FN_far_to_statistic,
    'FRR': FN_frr_to_statistic,
    'Precision': FN_precision_to_statistic,
    'Recall': FN_recall_to_statistic,
    'Time': FN_time_results_to_statistic
})
df_general.to_csv("FN_general_statistics.csv", index=False)

for fold in FN_ptr_results_to_statistic:
    df_perturbations = pd.DataFrame(fold)
    df_perturbations.to_csv("FN_perturbation_statistics.csv", index=False)
